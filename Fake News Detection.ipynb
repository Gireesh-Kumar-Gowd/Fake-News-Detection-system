# %% [markdown]
# # Importing the Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing the Dataset

# %%
dataset = pd.read_csv('FakeNewsNet.csv' ,  quoting = 3, on_bad_lines='skip')

# %% [markdown]
# # Data Analysis

# %%
dataset.isnull().sum()
# Out:
# title              0
# news_url         328
# source_domain    328
# tweet_num          0
# real               0
# dtype: int64

# %%
dataset.shape
# Out:
# (19896, 5)

# %%
dataset.head()
# Out:
#                                                title  \
# 0  Kandi Burruss Explodes Over Rape Accusation on...
# 1  People's Choice Awards 2018: The best red carp...
# 2  Sophia Bush Sends Sweet Birthday Message to 'O...
# 3  Colombian singer Maluma sparks rumours of inap...
# 4  Gossip Girl 10 Years Later: How Upper East Sid...
#
#                                             news_url        source_domain  \
# 0  http://toofab.com/2017/05/08/real-housewives-a...           toofab.com
# 1  https://www.today.com/style/see-people-s-choic...        www.today.com
# 2  https://www.etonline.com/news/220806_sophia_bu...     www.etonline.com
# 3  https://www.dailymail.co.uk/news/article-33655...  www.dailymail.co.uk
# 4  https://www.zerchoo.com/entertainment/gossip-g...      www.zerchoo.com
#
#    tweet_num  real
# 0         42     1
# 1          0     1
# 2         63     1
# 3         20     1
# 4         38     1

# %% [markdown]
# # Modelling on Balanced data

# %%
from sklearn.utils import resample

print(dataset['real'].value_counts())
# Out:
# real
# 1    15017
# 0     4879
# Name: count, dtype: int64

# %%
from sklearn.utils import resample

# Separate majority and minority classes
real_news = dataset[dataset['real'] == 1]
fake_news = dataset[dataset['real'] == 0]

# Upsample fake news to match real news count
fake_news_upsampled = resample(fake_news,
                               replace=True,
                               n_samples=len(real_news),
                               random_state=42)

# Combine upsampled fake news with real news
upsampled_dataset = pd.concat([real_news, fake_news_upsampled])
upsampled_dataset = upsampled_dataset.sample(frac=1, random_state=42).reset_index(drop=True)

# Split into features and target
X_balanced = upsampled_dataset.drop('real', axis=1)
y_balanced = upsampled_dataset['real']

# %%
print(X_balanced.head())
# Out:
#                                                title  \
# 0  7 Celebrity Summer Fashion Trends That Don't L...
# 1  Meghan Markle Is Invited to Pippa Middleton’s ...
# 2  Selena Gomez: Miley Cyrus Publicly Rejects Ple...
# 3                              General Gabbery: DWTS
# 4  Rihanna Sports Possible Baby Bump In Secret Ph...
#
#                                             news_url         source_domain  \
# 0  http://bojtv.com/7-celebrity-summer-fashion-tr...             bojtv.com
# 1  https://www.theknotnews.com/meghan-markle-harr...   www.theknotnews.com
# 2  hollywoodlife.com/2015/04/15/selena-gomez-mile...     hollywoodlife.com
# 3  http://forums.previously.tv/topic/3512-general...  forums.previously.tv
# 4      now100fm.com/rihanna-baby-bump-hassan-jameel/          now100fm.com
#
#    tweet_num
# 0         82
# 1         94
# 2         45
# 3         59
# 4         16

# %%
print(y_balanced.head())
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    0
# Name: real, dtype: int64

# %% [markdown]
# # Cleaning the Dataset

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(X_balanced.shape[0]):
  text = str(X_balanced['title'][i]) + ' ' + str(X_balanced['source_domain'][i])
  review = re.sub('[^a-zA-Z]',' ',text)
  review = review.lower()
  review = review.split()
  ps = PorterStemmer()
  review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
  review = ' '.join(review)
  corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
print(corpus)
# Out:
# ['celebr summer fashion trend look obviou bojtv com', 'meghan markl invit pippa middleton wed www theknotnew com', 'selena gomez miley cyru publicli reject plea end feud hollywoodlif com', 'gener gabberi dwt forum previous tv', 'rihanna sport possibl babi bump secret photo shoot pic fm com', 'robert pattinson charli hunnam lost citi z nan', 'deep throat download hq porn glabellar rssing com', 'nicol kidman prove clap normal seal like oscar mishap internet hyster www thesun co uk', 'skinni jean hater love bella hadid look www whowhatwear com', 'watch grammi award onlin www cb com', 'vanderpump rule cheat drama time vanderpump rule cast cheat www cosmopolitan com', 'democrat nation convent web archiv org', 'kim kardashian kany west secret pact fake marriag debunk www inquisitr com', 'tv show movi nomin golden globe www vultur com', 'tiffani haddish issa rae star jay z friend inspir moonlight video watch www etonlin com', 'madonna exhaust overwhelm book googl com', 'ashton kutcher celebr bachelor paradis return concern www thisisinsid com', 'barack obama twitter twitter com', 'new parent kyli jenner travi scott step smoothi dinner date peopl com', 'jennif lopez say relationship alex rodriguez one thing okmagazin com', 'scott disick thank kid ex kourtney kardashian see ador video peopl com', 'jennif aniston alway brad pitt greatest love celebrityinsid org', 'princ harri meghan markl date timelin www cosmopolitan com', 'khloe kardashian spoil tristan thompson father day want blow mind bed hollywoodlif com', 'backstag beauti zendaya hairstylist get readi faster www longroom com', 'rihanna hassan jameel two year surpris revel mean chri brown celebrityinsid org', 'justin bieber talk pastor carl lentz propos selena gomez www msn com', 'heather locklear join rhobh tasteofr com', 'westworld evan rachel wood tell dj khale grow make sex confess www digitalspi com', 'gigi hadid pull victoria secret fashion show follow racist buddha instagram video www standard co uk', 'john cena promis nikki bella make mom www dailymail co uk', 'selena gomez justin bieber jelenanetwork instagram photo video www instagram com', 'brad pitt use ex wife angelina joli alleg infidel court www ibtim com', 'jennif nettl releas new song king citi honor anniversari peopl com', 'khloe kardashian final open tristan thompson alleg infidel complet timelin cheat scandal www thisisinsid com', 'kany west reactiv instagram wish kim kardashian happi valentin day www etonlin com', 'see ashton kutcher kid onlin www thebump com', 'encyclopedia arkansa www encyclopediaofarkansa net', 'rumor bust prenup jennif lopez alex rodriguez extratv com', 'pari jackson makeup artist break hazi shadow trend comedyfe co uk', 'thor hulk fight thor ragnarok trailer first look excit www bustl com', 'burt ward celebr pay tribut batman star adam west ew com', 'fifti shade dakota thing peopl know dakota johnson www theth com', 'rachel lindsay obsess la base shirt brand www bustl com', 'sofia richi en wikipedia org', 'brian cassidi lawandord fandom com', 'whitney port talk surviv holiday travel new babi www parent com', 'angelina crisi joli beg brad pitt help starmagazin com', 'watch donald trump sketch snl play alec baldwin www nbc com', 'nicolett robinson en wikipedia org', 'rumor bust danni fujikawa dump pregnant gf kate hudson extratv com', 'matthew lewi strip itv drama girlfriend www dailymail co uk', 'sebastian stan reveal three secret aveng infin war cameo www newhot com', 'angelina joli threaten brad pitt bring kid around jennif aniston hollywoodlif com', 'aquaman movi reveal first look nicol kidman atlanna comicbook com', 'need know much ben affleck www washingtonpost com', 'kany west write book philosophi call break simul www complex com', 'michael strahan pick best holiday gift men one peopl com', 'ciara post photo first easter daughter sienna www upi com', 'zayn malik want call gigi hadid power coupl hellogiggl com', 'latest reveng news reveng spoiler collect sourc reveng headlin org reve ...

# %% [markdown]
# # Creating the bag of words model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(corpus)
y = y_balanced.values

# %%
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 313150 stored elements and shape (30034, 13249)>
#   Coords	Values
#   (0, 1864)	0.25738724233205645
#   (0, 11272)	0.38681565245294486
#   (0, 3992)	0.3403241031481714
#   (0, 12062)	0.39730560828533357
#   (0, 6849)	0.28141046168979217
#   (0, 8225)	0.5247012681806217
#   (0, 1241)	0.3889040668790725
#   (0, 2271)	0.06858261390191382
#   (1, 2271)	0.07379921872276067
#   (1, 7336)	0.27300974352680707
#   (1, 7151)	0.2782187874967749
#   (1, 5770)	0.42664566691275
#   (1, 8859)	0.4080032683032982
#   (1, 7445)	0.3191975485536433
#   (1, 12798)	0.2719929462637921
#   (1, 13110)	0.09216135242360167
#   (1, 11693)	0.5565604340923833
#   (2, 2271)	0.06177430556304451
#   (2, 10282)	0.23282321280635432
#   (2, 4747)	0.2352482898286267
#   (2, 7475)	0.2979228077354235
#   (2, 2726)	0.29506316548532147
#   (2, 9243)	0.4104267976509394
#   (2, 9580)	0.39916470183099323
#   (2, 8917)	0.4026467846651289
#   :	:
#   (30031, 9336)	0.36712937830576653
#   (30031, 9985)	0.4056184811178999
#   (30031, 10538)	0.46417592797470725
#   (30032, 2271)	0.0730872189050063
#   (30032, 13110)	0.09127219848314996
#   (30032, 1351)	0.25595113185667573
#   (30032, 8872)	0.25945500402366123
#   (30032, 385)	0.274437566367177
#   (30032, 6023)	0.275979104592947
#   (30032, 10929)	0.29075257358118756
#   (30032, 3711)	0.3149640865648392
#   (30032, 3805)	0.36110972241462846
#   (30032, 1039)	0.43393794605794095
#   (30032, 3620)	0.44674098947670715
#   (30033, 2271)	0.07209933825066851
#   (30033, 13110)	0.09003852123408711
#   (30033, 9588)	0.2986433013155849
#   (30033, 11770)	0.33537136635597814
#   (30033, 6354)	0.32167259854007496
#   (30033, 1162)	0.2928517841348008
#   (30033, 10444)	0.3070198024982656
#   (30033, 4973)	0.3119890468920166
#   (30033, 11077)	0.3161663998701658
#   (30033, 12651)	0.3718669934890912
#   (30033, 1981)	0.40737325567966143

# %%
print(y)
# Out:
# [1 1 0 ... 1 0 0]

# %% [markdown]
# # Splitting the Data set into the Traning set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2 ,stratify=y, random_state = 2)

# %% [markdown]
# # Training The Model Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression(random_state = 0, C= 10, max_iter= 100, penalty= 'l2', solver= 'liblinear')
LR.fit(X_train , y_train)
# Out:
# LogisticRegression(C=10, random_state=0, solver='liblinear')

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import confusion_matrix , accuracy_score
LR_y_pred = LR.predict(X_test)
cm = confusion_matrix(y_test , LR_y_pred)
print(cm)
accuracy_score(y_test , LR_y_pred)
# Out:
# [[2804  200]
#  [ 356 2647]]
# 0.9074413184617945

# %% [markdown]
# # K - Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score
LR_accuracies = cross_val_score(estimator = LR, X = X_train, y = y_train , cv = 10)
print("Accuracy : {:.2f}%".format(LR_accuracies.mean()*100))
print("Standard Deviation : {:.2f}%".format(LR_accuracies.std()*100))
# Out:
# Accuracy : 90.44%
# Standard Deviation : 0.52%

# %% [markdown]
# # Applying Grid Search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report

# Define the parameter grid
params = {
    'penalty': ['l1', 'l2'],
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear'],
    'max_iter': [100, 200]
}

# Create base model
lr = LogisticRegression(random_state=0)

# Set up Grid Search
grid = GridSearchCV(
    estimator=lr,
    param_grid=params,
    scoring='accuracy',
    cv=5,
    n_jobs=-1,
    error_score='raise'
)

# Fit on training data
grid.fit(X_train, y_train)

# Show best parameters and score
print("Best Parameters:", grid.best_params_)
print("Best Accuracy (CV):", grid.best_score_)

# Use best model to predict
best_lr = grid.best_estimator_
y_pred = best_lr.predict(X_test)

# Evaluate on test data
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'C': 10, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}
# Best Accuracy (CV): 0.9055229956657541
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.94      0.92      3004
#            1       0.94      0.89      0.91      3003
#
#     accuracy                           0.91      6007
#    macro avg       0.92      0.91      0.91      6007
# weighted avg       0.92      0.91      0.91      6007

# %% [markdown]
# # Training the Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators = 100, criterion = 'entropy',random_state = 0)
RF.fit(X_train , y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
RF_y_pred = RF.predict(X_test)
print(RF_y_pred)
# Out:
# [1 1 0 ... 0 0 1]

# %% [markdown]
# # Evaluation

# %%
RF_y_pred = RF.predict(X_test)
cm = confusion_matrix(y_test , RF_y_pred)
print(cm)
accuracy_score(y_test , RF_y_pred)
# Out:
# [[2893  111]
#  [ 214 2789]]
# 0.9458964541368403

# %% [markdown]
# # Training the model with Aritficial Neural Network

# %%
#importing the libraries
import tensorflow as tf
from tensorflow import keras
tf.random.set_seed(3)
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# #Building the Neural Network

# %%
#initializing neural network
ann = tf.keras.models.Sequential()

# %%
#adding the input layer
ann.add(tf.keras.layers.Dense(units = 32 , activation = 'relu'))
ann.add(Dropout(0.5))

# %%
#adding the second hidden layer
ann.add(tf.keras.layers.Dense(units = 32, activation = 'relu'))
ann.add(Dropout(0.5))

# %%
#adding the third hidden layer
ann.add(tf.keras.layers.Dense(units = 64, activation = 'relu'))
ann.add(Dropout(0.5))

# %%
#adding the output layer
ann.add(tf.keras.layers.Dense(units = 1,activation = 'sigmoid'))

# %% [markdown]
# # Training the Neural network

# %%
#compiling the neural network
ann.compile(optimizer = 'adam' , loss = 'binary_crossentropy' ,metrics = ['accuracy'])

# %%
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=6,
    restore_best_weights=True,
    mode='max'
)

# %%
#training the neural network
history = ann.fit(X_train, y_train, validation_split=0.2, epochs=20 ,batch_size=32, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.6518 - loss: 0.5978 - val_accuracy: 0.8700 - val_loss: 0.3208
# Epoch 2/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.8710 - loss: 0.3181 - val_accuracy: 0.8926 - val_loss: 0.2690
# Epoch 3/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9212 - loss: 0.2113 - val_accuracy: 0.9109 - val_loss: 0.2494
# Epoch 4/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9421 - loss: 0.1591 - val_accuracy: 0.9153 - val_loss: 0.2530
# Epoch 5/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9543 - loss: 0.1254 - val_accuracy: 0.9249 - val_loss: 0.2407
# Epoch 6/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9628 - loss: 0.1043 - val_accuracy: 0.9238 - val_loss: 0.2673
# Epoch 7/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9701 - loss: 0.0863 - val_accuracy: 0.9261 - val_loss: 0.2840
# Epoch 8/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9736 - loss: 0.0770 - val_accuracy: 0.9245 - val_loss: 0.2929
# Epoch 9/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 11s 11ms/step - accuracy: 0.9736 - loss: 0.0724 - val_accuracy: 0.9303 - val_loss: 0.2914
# Epoch 10/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9775 - loss: 0.0587 - val_accuracy: 0.9286 - val_loss: 0.3265
# Epoch 11/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9800 - loss: 0.0547 - val_accuracy: 0.9266 - val_loss: 0.3816
# Epoch 12/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9798 - loss: 0.0543 - val_accuracy: 0.9251 - val_loss: 0.3851
# Epoch 13/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9802 - loss: 0.0501 - val_accuracy: 0.9299 - val_loss: 0.3835
# Epoch 14/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9824 - loss: 0.0466 - val_accuracy: 0.9297 - val_loss: 0.3962
# Epoch 15/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 10s 11ms/step - accuracy: 0.9814 - loss: 0.0481 - val_accuracy: 0.9326 - val_loss: 0.3969
# Epoch 16/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9835 - loss: 0.0433 - val_accuracy: 0.9293 - val_loss: 0.4298
# Epoch 17/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9846 - loss: 0.0433 - val_accuracy: 0.9241 - val_loss: 0.4565
# Epoch 18/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9829 - loss: 0.0419 - val_accuracy: 0.9228 - val_loss: 0.4610
# Epoch 19/20
# 601/601 ━━━━━━━━━━━━━━━━━━━━ 7s 12ms/step - accuracy: 0.9855 - loss: 0.0392 - val_accuracy: 0.9197 - val_loss: 0.4721
# Epoch 20/20
# 407/601 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9837 - loss: 0.0384

# %%
loss, accuracy = ann.evaluate(X_test, y_test)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy )

# %%
#visualizing training accuracy and validation accuracy
h = history

plt.plot(h.history['accuracy'],label='train_accuracy')
plt.plot(h.history['val_accuracy'],label='val_accuracy')
plt.legend()
plt.show()

# %%
#visualizing training loss and validation loss

plt.plot(h.history['loss'] , label = 'train_loss')
plt.plot(h.history['val_loss'] , label = 'validation_loss')
plt.legend()
plt.show()

# %% [markdown]
# # Save , Load and building a predictive system

# %%
#saving the model
ann.save("FakeNewsNet.keras")

import joblib
joblib.dump(vectorizer, "vectorizer.joblib")

# %%
#loading the model
from tensorflow.keras.models import load_model
model = load_model("FakeNewsNet.keras")

vectorizer = joblib.load("vectorizer.joblib")

# %%
#building a prediction system
input_title = 'Gwen Stefani Got Dumped by Blake Shelton Over "Jealousy and Drama" (EXCLUSIVE)'
input_domain = 'www.intouchweekly.com'
user_input = input_title + ' ' + input_domain
user_input = re.sub('[^a-zA-Z]',' ',user_input)
user_input = user_input.lower()
user_input = user_input.split()
user_input = [ps.stem(word) for word in user_input if not word in set(stopwords.words('english'))]
user_input = ' '.join(user_input)
user_input_transformed = vectorizer.transform([user_input])
prediction = model.predict(user_input_transformed)
if float(prediction[0]) >= 0.5:
  print('It is a Fake News')
else:
  print('The News is Real')
